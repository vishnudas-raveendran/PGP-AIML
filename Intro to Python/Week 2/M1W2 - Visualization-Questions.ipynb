# %% [markdown]
# # Q.1 Import the libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %% [markdown]
# # Q.2 Get the Dataset

# %%
tips = pd.read_csv('tips.csv');
tips.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(tips.day.unique())
print(tips.time.unique())
print(tips.size.unique())  #doesn't work, whats the alternative for finding unique in numply.int32
# Out:
# ['Sun' 'Sat' 'Thur' 'Fri']
# ['Dinner' 'Lunch']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-431dd8d5752c> in <module>
#       1 print(tips.day.unique())
#       2 print(tips.time.unique())
# ----> 3 print(tips.size.unique())
#
# AttributeError: 'numpy.int32' object has no attribute 'unique'

# %%
tips.describe()
# Out:
#        Unnamed: 0  total_bill         tip        size
# count  244.000000  244.000000  244.000000  244.000000
# mean   121.500000   19.785943    2.998279    2.569672
# std     70.580923    8.902412    1.383638    0.951100
# min      0.000000    3.070000    1.000000    1.000000
# 25%     60.750000   13.347500    2.000000    2.000000
# 50%    121.500000   17.795000    2.900000    2.000000
# 75%    182.250000   24.127500    3.562500    3.000000
# max    243.000000   50.810000   10.000000    6.000000

# %% [markdown]
# # Q3. Plot the distribution of total_bill in the given dataset.

# %%
sns.distplot(tips['total_bill']);

# %% [markdown]
# # Q.4 - Plot the destribution plot for tips.

# %%
sns.distplot(tips['tip']);

# %% [markdown]
# # Q5. Make a joint plot between tip and total bill.

# %%
sns.jointplot(tips['total_bill'],tips['tip']);

# %% [markdown]
# # Q6. Give additional attribute kind = "hex" in the above plot.

# %%
sns.jointplot(tips['total_bill'],tips['tip'], kind="hex");

# %% [markdown]
# # Q7. Make pairplot between total bill and tip.

# %%
sns.pairplot(tips[['total_bill','tip']]);

# %% [markdown]
# # Q.8 -  Make striplot between sex and tip.

# %%
sns.stripplot(tips['sex'],tips['tip'], jitter=True);

# %%
sns.stripplot(tips['sex'],tips['total_bill'], jitter=True);

# %% [markdown]
# # Q.9 - What other plots you can make for tip and sex variable.Plot them.

# %%
sns.boxplot(tips['tip'],tips['sex'], hue=tips['sex']); ##why does this not make sense?

# %%
sns.pairplot(tips[['total_bill','tip',"size"]]);  ## no good

# %%
##Stacked example to find co-relation
subset = tips[["tip","total_bill","time"]]
sns.kdeplot(data=subset,x="total_bill", hue="time") 
#this example should have worked according to the docs 
#here http://seaborn.pydata.org/generated/seaborn.kdeplot.html#seaborn.kdeplot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-eb1d1fcb2409> in <module>
#       1 ##Stacked example to find co-relation
#       2 subset = tips[["tip","total_bill","time"]]
# ----> 3 sns.kdeplot(data=subset,x="total_bill", hue="time")
#       4 #this example should have worked according to the docs
#       5 #here http://seaborn.pydata.org/generated/seaborn.kdeplot.html#seaborn.kdeplot
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     665         return ax
#     666
# --> 667     data = data.astype(np.float64)
#     668     if data2 is not None:
#     669         if isinstance(data2, list):
#
# ...

# %% [markdown]
# The above example should have worked.... it didn't
# Source: http://seaborn.pydata.org/generated/seaborn.kdeplot.html#seaborn.kdeplot
# ![screenshot-seaborn.pydata.org-2021.03.19-22_53_28.jpg](attachment:screenshot-seaborn.pydata.org-2021.03.19-22_53_28.jpg)

# %%
sns.catplot(x="total_bill",y="day", hue="time",col="sex", data=tips, kind="bar")

# %% [markdown]
# # Q.10 Make bar plot with day and total bill.

# %%
sns.barplot(tips['total_bill'], tips['day'], hue=tips['time']);

# %% [markdown]
# # Q.11 - Make a plot to count total males and females for each day.

# %%
sns.countplot(tips['day'], hue=tips["sex"]);

# %%
sns.barplot(tips['tip'], tips['day'], hue=tips['time']);

# %% [markdown]
# # Q.12 -  Use factorplot to plot multiple categorical variables like day, smoker, peoplecount.

# %%
sns.catplot(x="day",y="size", hue="size",col="smoker", data=tips, kind="bar")

# %% [markdown]
# # Q.13 - Use lmplot() to plot the relation between total bill and tip.

# %%
sns.lmplot(x="total_bill",y="tip", hue="time",data=tips);

# %% [markdown]
# # Q.14 - Plot the above graph for male and female.

# %%
sns.lmplot(x="total_bill",y="tip", hue="sex",data=tips);

# %% [markdown]
# # Q.14 - Plot the Q.13 graph for smoker and non-smoker.

# %%
sns.lmplot(x="total_bill",y="tip", hue="smoker",data=tips);
